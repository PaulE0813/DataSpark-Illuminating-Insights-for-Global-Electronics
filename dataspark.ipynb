# %%
# importing library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Customers = pd.read_csv('Customers.csv', encoding = 'unicode_escape')
Customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
# checking its infomation

Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
# checking the sum of null value

Customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
#dropping null values 

Customers.drop(["State Code","Zip Code"],axis=1,inplace=True)

# %%
Customers.drop_duplicates(inplace=True)

# %%
# changing its dtype

Customers['Birthday'] = pd.to_datetime(Customers['Birthday'], format = '%m/%d/%Y')
Customers.head()
# Out:
#    CustomerKey  Gender               Name            City              State  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST    South Australia
# 1          325  Female       Madison Hull      MOUNT BUDD  Western Australia
# 2          554  Female      Claire Ferres       WINJALLOK           Victoria
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER    South Australia
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH           Victoria
#
#      Country  Continent   Birthday
# 0  Australia  Australia 1939-07-03
# 1  Australia  Australia 1979-09-27
# 2  Australia  Australia 1947-05-26
# 3  Australia  Australia 1957-09-17
# 4  Australia  Australia 1965-11-19

# %%
print(Customers.dtypes)
print('--------------------------------------------------')
print(Customers.isnull().sum())
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State                  object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object
# --------------------------------------------------
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State          0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
Customers.describe()   # knowing the statistics
# Out:
#         CustomerKey                       Birthday
# count  1.526600e+04                          15266
# mean   1.060508e+06  1968-09-20 13:51:07.050962920
# min    3.010000e+02            1935-02-03 00:00:00
# 25%    5.140335e+05            1952-02-10 06:00:00
# 50%    1.079244e+06            1968-07-25 12:00:00
# 75%    1.593980e+06            1985-06-09 18:00:00
# max    2.099937e+06            2002-02-18 00:00:00
# std    6.127097e+05                            NaN

# %%
# Saving the cleaned data to csv file 
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Cleaned - Customers.csv"
Customers.to_csv(path,index=False)

# %%
Sales = pd.read_csv('Sales.csv')
Sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
Sales.info()           # checking its information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
Sales.isnull().sum()         # checking the sum of null value
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
Sales['Delivery Date'] = Sales['Delivery Date'].fillna(Sales['Order Date'])     
# filling the null values of Delivery Date BY Order Date

Sales['Delivery Date'] = pd.to_datetime(Sales['Delivery Date'], format="%m/%d/%Y", errors='coerce').dt.date

# %%
# changing its dtype
Sales['Order Date'] = pd.to_datetime(Sales['Order Date'])

# %%
Sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01    2016-01-01       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20    2021-02-20      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
print(Sales.dtypes)
print('--------------------------------------------------')
print(Sales.isnull().sum())
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# Delivery Date            object
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object
# --------------------------------------------------
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
Sales.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1 2016-01-01    2016-01-01       265598        10
# 1        366001          1 2016-01-01    2016-01-13      1269051         0
# 2        366001          2 2016-01-01    2016-01-13      1269051         0
# 3        366002          1 2016-01-01    2016-01-12       266019         0
# 4        366002          2 2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
Sales.describe()         # knowing its statistics
# Out:
#        Order Number     Line Item                     Order Date  \
# count  6.288400e+04  62884.000000                          62884
# mean   1.430905e+06      2.164207  2018-11-30 21:21:56.939126016
# min    3.660000e+05      1.000000            2016-01-01 00:00:00
# 25%    1.121017e+06      1.000000            2018-01-25 00:00:00
# 50%    1.498016e+06      2.000000            2019-02-06 00:00:00
# 75%    1.788010e+06      3.000000            2019-11-23 00:00:00
# max    2.243032e+06      7.000000            2021-02-20 00:00:00
# std    4.532963e+05      1.365170                            NaN
#
#         CustomerKey      StoreKey    ProductKey      Quantity
# count  6.288400e+04  62884.000000  62884.000000  62884.000000
# mean   1.180797e+06     31.802144   1125.859344      3.144790
# min    3.010000e+02      0.000000      1.000000      1.000000
# 25%    6.808580e+05      8.000000    437.000000      1.000000
# 50%    1.261200e+06     37.000000   1358.000000      2.000000
# ...

# %%
# Saving the cleaned data to csv file 
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Cleaned - Sales.csv"
Sales.to_csv(path,index=False)

# %%
Exchange_Rates = pd.read_csv('Exchange_Rates.csv')
Exchange_Rates
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
Exchange_Rates.info()              
# checking its information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
Exchange_Rates.isnull().sum()         
# checkinng the sum of null values
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
Exchange_Rates['Date'] = pd.to_datetime(Exchange_Rates['Date'])             
# changing its dtype

# %%
Exchange_Rates
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
print(Exchange_Rates.dtypes)
print('--------------------------------------------------')
print(Exchange_Rates.isnull().sum())
# Out:
# Date        datetime64[ns]
# Currency            object
# Exchange           float64
# dtype: object
# --------------------------------------------------
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
Exchange_Rates.head()           # getting first 5 tables
# Out:
#         Date Currency  Exchange
# 0 2015-01-01      USD    1.0000
# 1 2015-01-01      CAD    1.1583
# 2 2015-01-01      AUD    1.2214
# 3 2015-01-01      EUR    0.8237
# 4 2015-01-01      GBP    0.6415

# %%
Exchange_Rates.describe()             # knowing its statistics
# Out:
#                       Date      Exchange
# count                11215  11215.000000
# mean   2018-01-26 00:00:00      1.061682
# min    2015-01-01 00:00:00      0.628500
# 25%    2016-07-14 00:00:00      0.857800
# 50%    2018-01-26 00:00:00      1.000000
# 75%    2019-08-10 00:00:00      1.311900
# max    2021-02-20 00:00:00      1.725300
# std                    NaN      0.245519

# %%
# Saving the cleaned data to csv file 
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Cleaned - Exchange_Rates.csv"
Exchange_Rates.to_csv(path,index=False)

# %%
Products = pd.read_csv('Products.csv')
Products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
Products.info()                   # checking its information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
Products.isnull().sum()           
 # checking the sum of null values
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
# chaging its dtype and replacing few strings
Products['Unit Cost USD'] = Products['Unit Cost USD'].str.replace('$', '').str.replace(",", "").str.strip().astype(float)
Products['Unit Price USD'] = Products['Unit Price USD'].str.replace('$', '').str.replace(",", "").str.strip().astype(float)

# %%
Products.dtypes
# Out:
# ProductKey          int64
# Product Name       object
# Brand              object
# Color              object
# Unit Cost USD     float64
# Unit Price USD    float64
# SubcategoryKey      int64
# Subcategory        object
# CategoryKey         int64
# Category           object
# dtype: object

# %%
Products.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           7.40           14.52             101     MP4&MP3            1
# 3          11.00           21.57             101     MP4&MP3            1
# 4          11.00           21.57             101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
Products.describe()
# Out:
#         ProductKey  Unit Cost USD  Unit Price USD  SubcategoryKey  CategoryKey
# count  2517.000000    2517.000000     2517.000000     2517.000000  2517.000000
# mean   1259.000000     147.655562      356.830131      491.810091     4.878824
# std     726.739637     184.373683      494.054962      229.887134     2.299170
# min       1.000000       0.480000        0.950000      101.000000     1.000000
# 25%     630.000000      32.250000       69.000000      305.000000     3.000000
# 50%    1259.000000      86.670000      199.990000      406.000000     4.000000
# 75%    1888.000000     183.950000      410.000000      801.000000     8.000000
# max    2517.000000    1060.220000     3199.990000      808.000000     8.000000

# %%
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Cleaned - Products.csv"
Products.to_csv(path,index=False)

# %%
Stores = pd.read_csv('Stores.csv')
Stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
Stores.info()                 
# checking its information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
Stores.isnull().sum()            
# checking the sum of null values
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
Stores = Stores.dropna()

# %%
Stores['Open Date'] = pd.to_datetime(Stores['Open Date'])       
 # changing its dtype
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_19916\2674263983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Stores['Open Date'] = pd.to_datetime(Stores['Open Date'])

# %%
Stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 61        62  United States                  South Dakota         1120.0
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
print(Stores.dtypes)
print('--------------------------------------------------')
print(Stores.isnull().sum())
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters           float64
# Open Date        datetime64[ns]
# dtype: object
# --------------------------------------------------
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
Stores.describe()
# Out:
#         StoreKey  Square Meters                      Open Date
# count  66.000000      66.000000                             66
# mean   33.500000    1402.196970  2011-07-02 04:43:38.181818112
# min     1.000000     245.000000            2005-03-04 00:00:00
# 25%    17.250000    1108.750000            2009-06-03 00:00:00
# 50%    33.500000    1347.500000            2011-03-18 12:00:00
# 75%    49.750000    2000.000000            2013-06-07 00:00:00
# max    66.000000    2105.000000            2019-03-05 00:00:00
# std    19.196354     576.404058                            NaN

# %%
# Saving the cleaned data to csv file 
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Cleaned - Stores.csv"
Stores.to_csv(path,index=False)

# %%
# Merging the Data's
# reading all the cleaned csv files

Customer = pd.read_csv("Cleaned - Customers.csv")
Sale = pd.read_csv("Cleaned - Sales.csv")
Exchange_Rate = pd.read_csv("Cleaned - Exchange_Rates.csv")
Products = pd.read_csv("Cleaned - Products.csv")
Store = pd.read_csv("Cleaned - Stores.csv")

# %%
# Merging Sales and Customer

# Merging Sales with Customers on CustomerKey
Sales_Customers = Sale.merge(Customer, on='CustomerKey', how='left')
Sales_Customers
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01    2016-01-01       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20    2021-02-20      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  \
# 0            10        1304         1           CAD    Male
# ...

# %%
Sales_Customers.isnull().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# Gender           0
# Name             0
# City             0
# State            0
# Country          0
# Continent        0
# Birthday         0
# dtype: int64

# %%
Sales_Customers = Sales_Customers.dropna()                   # dropping the null values

# %%
# checking the sum of null values after dropping the null values
Sales_Customers.isnull().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# Gender           0
# Name             0
# City             0
# State            0
# Country          0
# Continent        0
# Birthday         0
# dtype: int64

# %%
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Sales_Customers.csv"
Sales_Customers.to_csv(path,index=False)

# %%
# Merging Sales and Products

# Merging Sales with Products on ProductKey

Sales_Products = Sale.merge(Products, on='ProductKey', how='left')
Sales_Products
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01    2016-01-01       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20    2021-02-20      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  \
# 0            10        1304         1           CAD
# ...

# %%
Sales_Products.isnull().sum()            
# checking the sum of null values
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# Delivery Date     0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Sales_Products.csv"
Sales_Products.to_csv(path,index=False)

# %%
# Merging Sales and Stores

# Merging Sales with Stores on StoreKey

Sales_Stores = Sale.merge(Store, on='StoreKey', how='left')
Sales_Stores
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01    2016-01-01       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20    2021-02-20      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code        Country    State  \
# ...

# %%
Sales_Stores.isnull().sum()            # checking the sum of null values
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date        0
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# Country          13165
# State            13165
# Square Meters    13165
# Open Date        13165
# dtype: int64

# %%
Sales_Stores = Sales_Stores.dropna()                 # dropping the null values

# %%
Sales_Stores.isnull().sum()               # checking the sum of null values after dropping the null values
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
Sales_Stores
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01    2016-01-01       265598
# 6            366004          1  2016-01-01    2016-01-01      1107461
# 7            366004          2  2016-01-01    2016-01-01      1107461
# 8            366005          1  2016-01-01    2016-01-01       844003
# 9            366007          1  2016-01-01    2016-01-01      2035771
# ...             ...        ...         ...           ...          ...
# 62867       2243025          1  2021-02-20    2021-02-20      1909290
# 62868       2243025          2  2021-02-20    2021-02-20      1909290
# 62869       2243026          1  2021-02-20    2021-02-20      1737466
# 62872       2243028          1  2021-02-20    2021-02-20      1728060
# 62879       2243030          1  2021-02-20    2021-02-20      1216913
#
#        StoreKey  ProductKey  Quantity Currency Code         Country  \
# ...

# %%
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Sales_Stores.csv"
Sales_Stores.to_csv(path,index=False)

# %%
# Merging Sales with Stores on StoreKey
Sales_Exchange_Rate = Sale.merge(Exchange_Rate, left_on=['Order Date', 'Currency Code'], right_on=['Date', 'Currency'], how='left')
Sales_Exchange_Rate
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01    2016-01-01       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20    2021-02-20      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code        Date Currency  \
# ...

# %%
Sales_Exchange_Rate.isnull().sum()          
# checking the sum of null values
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# Date             0
# Currency         0
# Exchange         0
# dtype: int64

# %%
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Sales_ExchangeRate.csv"
Sales_Exchange_Rate.to_csv(path,index=False)

# %%
# Merge sales_customers with products
Sales_Customers_Products = Sales_Customers.merge(Products, on='ProductKey', how='left')
Sales_Customers_Products
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01    2016-01-01       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20    2021-02-20      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  ...    Birthday  \
# ...

# %%
Sales_Customers_Products.isnull().sum()              # checking the sum of null values
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# Delivery Date     0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Gender            0
# Name              0
# City              0
# State             0
# Country           0
# Continent         0
# Birthday          0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Sales_Customers_Products.csv"
Sales_Customers_Products.to_csv(path,index=False)

# %%
# Merge sales_customers_products with stores
Sales_Customers_Products_Stores = Sales_Customers_Products.merge(Store, on='StoreKey', how='left')
Sales_Customers_Products_Stores
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01    2016-01-01       265598
# 1            366001          1  2016-01-01    2016-01-13      1269051
# 2            366001          2  2016-01-01    2016-01-13      1269051
# 3            366002          1  2016-01-01    2016-01-12       266019
# 4            366002          2  2016-01-01    2016-01-12       266019
# ...             ...        ...         ...           ...          ...
# 62879       2243030          1  2021-02-20    2021-02-20      1216913
# 62880       2243031          1  2021-02-20    2021-02-24       511229
# 62881       2243032          1  2021-02-20    2021-02-23       331277
# 62882       2243032          2  2021-02-20    2021-02-23       331277
# 62883       2243032          3  2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# ...

# %%
Sales_Customers_Products_Stores.isnull().sum()
# Out:
# Order Number          0
# Line Item             0
# Order Date            0
# Delivery Date         0
# CustomerKey           0
# StoreKey              0
# ProductKey            0
# Quantity              0
# Currency Code         0
# Gender                0
# Name                  0
# City                  0
# State_x               0
# Country_x             0
# Continent             0
# Birthday              0
# Product Name          0
# Brand                 0
# Color                 0
# Unit Cost USD         0
# Unit Price USD        0
# SubcategoryKey        0
# Subcategory           0
# CategoryKey           0
# Category              0
# Country_y         13165
# State_y           13165
# Square Meters     13165
# Open Date         13165
# dtype: int64

# %%
Sales_Customers_Products_Stores = Sales_Customers_Products_Stores.dropna()            # dropping the null values

# %%
Sales_Customers_Products_Stores.isnull().sum()              # checking the sum of null values after dropping the null values
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# Delivery Date     0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Gender            0
# Name              0
# City              0
# State_x           0
# Country_x         0
# Continent         0
# Birthday          0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# Country_y         0
# State_y           0
# Square Meters     0
# Open Date         0
# dtype: int64

# %%
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Sales_Customers_Products_Stores.csv"
Sales_Customers_Products_Stores.to_csv(path,index=False)

# %%
# Merging Sales_Customers_Products_stores with Exchange Rates 
final_merged_data = Sales_Customers_Products_Stores.merge(Exchange_Rate, left_on=['Order Date', 'Currency Code'], right_on=['Date', 'Currency'], how='left')
final_merged_data
# Out:
#        Order Number  Line Item  Order Date Delivery Date  CustomerKey  \
# 0            366000          1  2016-01-01    2016-01-01       265598
# 1            366004          1  2016-01-01    2016-01-01      1107461
# 2            366004          2  2016-01-01    2016-01-01      1107461
# 3            366005          1  2016-01-01    2016-01-01       844003
# 4            366007          1  2016-01-01    2016-01-01      2035771
# ...             ...        ...         ...           ...          ...
# 49714       2243025          1  2021-02-20    2021-02-20      1909290
# 49715       2243025          2  2021-02-20    2021-02-20      1909290
# 49716       2243026          1  2021-02-20    2021-02-20      1737466
# 49717       2243028          1  2021-02-20    2021-02-20      1728060
# 49718       2243030          1  2021-02-20    2021-02-20      1216913
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# ...

# %%
final_merged_data.isnull().sum()           # checking the sum of null values
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# Delivery Date     0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Gender            0
# Name              0
# City              0
# State_x           0
# Country_x         0
# Continent         0
# Birthday          0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# Country_y         0
# State_y           0
# Square Meters     0
# Open Date         0
# Date              0
# Currency          0
# Exchange          0
# dtype: int64

# %%
path=r"C:/Users/Priya/OneDrive/Desktop/Dataspark/Merged_data.csv"
final_merged_data.to_csv(path,index=False)

# %%
# EDA

eda = pd.read_csv('Merged_data.csv')

# %%
# Calulating Age
Customer['Age'] = pd.to_datetime('today').year - pd.to_datetime(Customer['Birthday']).dt.year

# Distribution by Age 
sns.histplot(Customer['Age'], bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Preferred Products
preferred_products = eda['Product Name'].value_counts().head(20)

# Donut chat for Preferred Products
plt.figure(figsize=(10, 8))
plt.pie(preferred_products, labels=preferred_products.index, autopct='%1.1f%%', startangle=140)
centre_circle = plt.Circle((0, 0), 0.70, color='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('20 Preferred Products')
plt.tight_layout()
plt.show()

# %%
# Group by store and sum the 'Order Value'

eda['Order Value'] = eda['Quantity'] * eda['Unit Price USD']

# Group by currency code and sum the 'Order Value'

Sales_by_Currency = eda.groupby('Currency Code')['Order Value'].sum()

# Plotting sales by currency
plt.figure(figsize=(8,6))
plt.pie(Sales_by_Currency, labels=Sales_by_Currency.index, autopct='%1.1f%%', startangle=0)
plt.title('Sales Performance by Currency ')
plt.show()

# %%
# Calculate Order Value (Total Revenue) for each product
eda['Order Value'] = eda['Quantity'] * eda['Unit Price USD']

# Calculate profit for each product
eda['Profit'] = eda['Unit Price USD'] - eda['Unit Cost USD']

# Calculate total profit for each product based on quantity sold
eda['Total Profit'] = eda['Profit'] * eda['Quantity']

# Calculate profit margin for each product
eda['Profit Margin'] = (eda['Profit'] / eda['Unit Price USD']) * 100  # Profit Margin as a percentage of selling price

# Group by 'Product Name' and calculate total revenue, total profit, and average profit margin
profitability = eda.groupby('Product Name').agg(
    Total_Revenue=('Order Value', 'sum'),
    Total_Profit=('Total Profit', 'sum'),
    Avg_Profit_Margin=('Profit Margin', 'mean')
).reset_index()

# profit margin
top_profitable_products = profitability.sort_values(by='Avg_Profit_Margin')

plt.figure(figsize=(10, 6))
sns.violinplot(x=profitability['Avg_Profit_Margin'], color='green')
plt.title('Violin Plot of Average Profit Margin Across Products')
plt.xlabel('Profit Margin (%)')
plt.show()

# %%
# Calculate total quantity for each Category
Category_performance = eda.groupby(['Category']).agg(
    Total_Quantity=('Quantity', 'sum')
).reset_index()

# Sort subcategories by total quantity
Category_performance = Category_performance.sort_values(by='Total_Quantity', ascending=False)

# Plotting a simple bar chart
plt.figure(figsize=(15, 10))
sns.barplot(data=Category_performance, x='Category', y='Total_Quantity')
plt.title('Total Quantity Sold by Category')
plt.xlabel('Category')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# importing library  SQL

import psycopg2

con= psycopg2.connect(
    host="localhost",
    user="postgres",
    password="priya1",
    database="data",
    port="5432"
    )
mycursor=con.cursor()

# %%
df_customers = pd.read_csv('Customers.csv', encoding = 'unicode_escape')
df_exchange_rates = pd.read_csv("Exchange_Rates.csv")
df_products = pd.read_csv("Products.csv")
df_stores = pd.read_csv("Stores.csv")
df_sales = pd.read_csv("Sales.csv")

# %%
con.commit()

# %%
# Creating Table Customers
mycursor.execute('''CREATE TABLE customers(
        ID BIGINT PRIMARY KEY,
        CustomerKey BIGINT,
        Gender VARCHAR(25) NOT NULL ,
        Customer_Name VARCHAR(50) NOT NULL,
        City VARCHAR(50) NOT NULL,
        State_Code VARCHAR(50) NOT NULL,
        State VARCHAR(50) NOT NULL,
        Zip_Code VARCHAR(10) NOT NULL,
        Country VARCHAR(50) NOT NULL,
        Continent VARCHAR(50) NOT NULL,
        Birthday VARCHAR(50) NOT NULL
    )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
#customer table creation
mycursor.execute('''CREATE TABLE customers(
                  CustomerKey BIGINT,
                  Gender VARCHAR,
                  Name VARCHAR,
                  City VARCHAR,
                  State VARCHAR,
                  Country VARCHAR,
                  Continent VARCHAR,
                  Birthday DATE
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
# insert values into customer table
insert_query='''INSERT INTO customers(
                  CustomerKey,
                  Gender,
                  Name,
                  City,
                  State,
                  Country,
                  Continent,
                  Birthday)
                  VALUES(%s,%s,%s,%s,%s,%s,%s,%s)'''
print("Inserted successfully")
# Out:
# Inserted successfully

# %%
# exchange_rates table creation
mycursor.execute('''CREATE TABLE exchange_rates(
                  Date DATE,
                  Currency_Code VARCHAR(255),
                  Exchange FLOAT
                  )''')
print("Table Created successfully")

# insert values into exchange_rates table
insert_query ='''INSERT INTO exchange_rates(
                  Date,
                  Currency_Code,
                  Exchange)
                  VALUES (%s, %s, %s)'''
print("Inserted successfully")
# Out:
# Table Created successfully
# Inserted successfully

# %%
# create Products table 
mycursor.execute('''CREATE TABLE products(
                  ProductKey BIGINT,
                  Product_Name VARCHAR(255),
                  Brand VARCHAR(255),
                  Color VARCHAR(255),
                  Unit_Cost_USD FLOAT,
                  Unit_Price_USD FLOAT,
                  Subcategory VARCHAR(255),
                  CategoryKey BIGINT,
                  Category VARCHAR(255)
                  )''')
print("Table Created successfully")

#insert values into Products table
insert_query ='''INSERT INTO products(
                  ProductKey,
                  Product_Name,
                  Brand,
                  Color,
                  Unit_Cost_USD,
                  Unit_Price_USD,
                  Subcategory,
                  CategoryKey,
                  Category)
                  VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s)'''
print("Inserted successfully")
# Out:
# Table Created successfully
# Inserted successfully

# %%
con.rollback()
con.commit()

# %%
#sales table creation
mycursor.execute('''CREATE TABLE sales(
                  Order_Number BIGINT,
                  Line_Item BIGINT,
                  Order_Date DATE,
                  Delivery_Date DATE,
                  CustomerKey BIGINT,
                  StoreKey BIGINT,
                  ProductKey BIGINT,
                  Quantity BIGINT,
                  Currency_Code VARCHAR(255)
                  )''')
print("Table Created successfully")

#insert values into sales table
insert_query ='''INSERT INTO sales(
                  Order_Number,
                  Line_Item,
                  Order_Date,
                  Delivery_Date,
                  CustomerKey,
                  StoreKey,
                  ProductKey,
                  Quantity,
                  Currency_Code)
                  VALUES (%s, %s, %s, %s, %s, %s, %s, %s,%s)'''
print("Inserted successfully")
# Out:
# Table Created successfully
# Inserted successfully

# %%
#store table creation
mycursor.execute('''CREATE TABLE stores(
                  StoreKey INT,
                  Country VARCHAR(255),
                  State VARCHAR(255),
                  Square_Meters FLOAT,
                  Open_Date DATE
                  )''')
print("Table Created successfully")

df_stores.fillna(0)  
##insert values into Store table
insert_query ='''INSERT INTO stores(
                  StoreKey,
                  Country,
                  State,
                  Square_Meters,
                  Open_Date)
                  VALUES (%s, %s, %s, %s, %s)'''
print("Inserted successfully")
# Out:
# Table Created successfully
# Inserted successfully

# %% [markdown]
# select * from customer;
# select * from exchange_rates;
# select * from products;
# select * from sales;
# select * from stores;
#
# -- Queries for insights
#
# -- 1. Overall female count
# SELECT COUNT(Gender) AS Female_count
# FROM customers
# WHERE Gender = "Female";
#
# -- 2. Overall male count
# SELECT COUNT(Gender) AS Male_count
# FROM customers
# WHERE Gender = "Male";
#
# -- 3. Count of customers by country
# SELECT sd.Country, COUNT(DISTINCT c.CustomerKey) AS customer_count
# FROM sales c
# JOIN stores sd ON c.StoreKey = sd.StoreKey
# GROUP BY sd.Country
# ORDER BY customer_count DESC;
#
# -- 4. Overall count of customers
# SELECT COUNT(DISTINCT s.CustomerKey) AS customer_count
# FROM sales s;
#
# -- 5. Count of stores by country
# SELECT Country, COUNT(StoreKey)
# FROM stores
# GROUP BY Country
# ORDER BY COUNT(StoreKey) DESC;
#
# -- 6. Store-wise sales
# SELECT s.StoreKey, sd.Country, SUM(pd.Unit_Price_USD * s.Quantity) AS total_sales_amount
# FROM products pd
# JOIN sales s ON pd.ProductKey = s.ProductKey
# JOIN stores sd ON s.StoreKey = sd.StoreKey
# GROUP BY s.StoreKey, sd.Country;
#
# -- 7. Overall selling amount
# SELECT SUM(pd.Unit_Price_USD * sd.Quantity) AS total_sales_amount
# FROM productss pd
# JOIN sales sd ON pd.ProductKey = sd.ProductKey;
#
# -- 8. Brand count
# SELECT Brand, COUNT(Brand) AS brand_count
# FROM products
# GROUP BY Brand;
#
# -- 9. CP and SP difference and profit
# SELECT Unit_price_USD, Unit_Cost_USD,
#        ROUND((Unit_price_USD - Unit_Cost_USD), 2) AS diff,
#        ROUND(((Unit_price_USD - Unit_Cost_USD) / Unit_Cost_USD) * 100, 2) AS profit_percent
# FROM products;
#
# -- 10. Brand-wise selling amount
# SELECT Brand, ROUND(SUM(pd.Unit_price_USD * sd.Quantity), 2) AS sales_amount
# FROM products pd
# JOIN sales sd ON pd.ProductKey = sd.ProductKey
# GROUP BY Brand;
#
# -- 11. Subcategory-wise selling amount
# SELECT Subcategory, COUNT(Subcategory)
# FROM products
# GROUP BY Subcategory;
#
# -- Subcategory-wise total sales
# SELECT Subcategory, ROUND(SUM(pd.Unit_price_USD * sd.Quantity), 2) AS TOTAL_SALES_AMOUNT
# FROM products pd
# JOIN sales sd ON pd.ProductKey = sd.ProductKey
# GROUP BY Subcategory
# ORDER BY TOTAL_SALES_AMOUNT DESC;
#
# -- 12. Country overall sales
# SELECT s.Country, SUM(pd.Unit_price_USD * sd.Quantity) AS total_sales
# FROM products pd
# JOIN sales sd ON pd.ProductKey = sd.ProductKey
# JOIN stores s ON sd.StoreKey = s.StoreKey
# GROUP BY s.Country;
#
# -- 13. Year-wise brand sales
# SELECT YEAR(Order_Date), pd.Brand,
#        ROUND(SUM(pd.Unit_price_USD * sd.Quantity), 2) AS year_sales
# FROM sales sd
# JOIN products pd ON sd.ProductKey = pd.ProductKey
# GROUP BY YEAR(Order_Date), pd.Brand;
#
# -- 14. Month-wise sales
# SELECT MONTH(Order_Date), SUM(pd.Unit_price_USD * sd.Quantity) AS sp_month
# FROM sales sd
# JOIN products pd ON sd.ProductKey = pd.ProductKey
# GROUP BY MONTH(Order_Date);
#
# -- 15. Month and year-wise sales with quantity
# SELECT MONTH(Order_Date), YEAR(Order_Date), pd.Brand,
#        SUM(pd.Unit_price_USD * sd.Quantity) AS sp_month
# FROM sales sd
# JOIN products pd ON sd.ProductKey = pd.ProductKey
# GROUP BY MONTH(Order_Date), YEAR(Order_Date), pd.Brand;
#
# -- 16. Year-wise sales
# SELECT YEAR(Order_Date), SUM(pd.Unit_price_USD * sd.Quantity) AS sp_month
# FROM sales sd
# JOIN products pd ON sd.ProductKey = pd.ProductKey
# GROUP BY YEAR(Order_Date);
#
# -- 17. Comparing current month and previous month sales
# SELECT YEAR(Order_Date), MONTH(Order_Date),
#        ROUND(SUM(pd.Unit_Price_USD * sd.Quantity), 2) AS sales,
#        LAG(ROUND(SUM(pd.Unit_Price_USD * sd.Quantity), 2))
#        OVER (ORDER BY YEAR(Order_Date), MONTH(Order_Date)) AS Previous_Month_Sales
# FROM sales sd
# JOIN products pd ON sd.ProductKey = pd.ProductKey
# GROUP BY YEAR(Order_Date), MONTH(Order_Date);
#
# -- 18. Year-wise profit
# SELECT YEAR(Order_Date) AS Year,
#        (SUM(pd.Unit_Price_USD * sd.Quantity) - SUM(pd.Unit_Cost_USD * sd.Quantity)) AS sales,
#        LAG(SUM(pd.Unit_Price_USD * sd.Quantity) - SUM(pd.Unit_Cost_USD * sd.Quantity))
#        OVER (ORDER BY YEAR(Order_Date)) AS Previous_year_Sales,
#        ROUND(((SUM(pd.Unit_Price_USD * sd.Quantity) - SUM(pd.Unit_Cost_USD * sd.Quantity)) -
#        LAG(SUM(pd.Unit_Price_USD * sd.Quantity) - SUM(pd.Unit_Cost_USD * sd.Quantity))
#        OVER (ORDER BY YEAR(Order_Date))) / LAG(SUM(pd.Unit_Price_USD * sd.Quantity) - SUM(pd.Unit_Cost_USD * sd.Quantity))
#        OVER (ORDER BY YEAR(Order_Date)) * 100, 2) AS profit_percent
# FROM sales sd
# JOIN products pd ON sd.ProductKey = pd.ProductKey
# GROUP BY YEAR(Order_Date);
